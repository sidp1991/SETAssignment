# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
import pandas as pd
data=pd.read_csv("day.csv")
data.head()
# Out:
#    instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 0        1  2011-01-01       1   0  ...   0.160446     331         654   985
# 1        2  2011-01-02       1   0  ...   0.248539     131         670   801
# 2        3  2011-01-03       1   0  ...   0.248309     120        1229  1349
# 3        4  2011-01-04       1   0  ...   0.160296     108        1454  1562
# 4        5  2011-01-05       1   0  ...   0.186900      82        1518  1600
#
# [5 rows x 16 columns]

# %%
data.shape
data.describe
# Out:
# <bound method NDFrame.describe of      instant      dteday  season  yr  ...  windspeed  casual  registered   cnt
# 0          1  2011-01-01       1   0  ...   0.160446     331         654   985
# 1          2  2011-01-02       1   0  ...   0.248539     131         670   801
# 2          3  2011-01-03       1   0  ...   0.248309     120        1229  1349
# 3          4  2011-01-04       1   0  ...   0.160296     108        1454  1562
# 4          5  2011-01-05       1   0  ...   0.186900      82        1518  1600
# ..       ...         ...     ...  ..  ...        ...     ...         ...   ...
# 726      727  2012-12-27       1   1  ...   0.350133     247        1867  2114
# 727      728  2012-12-28       1   1  ...   0.155471     644        2451  3095
# 728      729  2012-12-29       1   1  ...   0.124383     159        1182  1341
# 729      730  2012-12-30       1   1  ...   0.350754     364        1432  1796
# 730      731  2012-12-31       1   1  ...   0.154846     439        2290  2729
#
# [731 rows x 16 columns]>

# %%
data= data.drop(columns=['dteday','instant'])

# %%
from sklearn import preprocessing
x=data.drop(['cnt'],axis=1)
y=data['cnt']
x = preprocessing.normalize(x)

# %%
data.columns
# Out:
# Index(['season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
linearRegressor = LinearRegression()
linearRegressor.fit(x_train, y_train)
y_predicted = linearRegressor.predict(x_test)
mse = mean_squared_error(y_test, y_predicted)
r = r2_score(y_test, y_predicted)
mae = mean_absolute_error(y_test,y_predicted)
print("Mean Squared Error:",mse)
print("R score:",r)
print("Mean Absolute Error:",mae)
# Out:
# Mean Squared Error: 2715595.074749046
# R score: 0.3420106093390981
# Mean Absolute Error: 1180.139412566995

# %%
from sklearn import preprocessing
x=data[['weekday']]
y=data['cnt']

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
lr = LinearRegression()
lr.fit(x_train, y_train)
y_predicted = lr.predict(x_test)
mse = mean_squared_error(y_test, y_predicted)
r = r2_score(y_test, y_predicted)
mae = mean_absolute_error(y_test,y_predicted)
print("Mean Squared Error:",mse)
print("R score:",r)
print("Mean Absolute Error:",mae)
import math

from sklearn.metrics import mean_squared_error

rmse = math.sqrt(mean_squared_error(y_test, y_predicted))

print(rmse)

lr.predict([[0]])
# Out:
# Mean Squared Error: 4099984.5641900413
# R score: 0.006572677128671822
# Mean Absolute Error: 1669.9130200833765
# 2024.841861526485
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   "X does not have valid feature names, but"
# array([4333.02033271])
